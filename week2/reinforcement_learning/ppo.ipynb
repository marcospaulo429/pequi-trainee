# %% [markdown]
# Install the tools

# %%
#!pip install torch numpy==1.23.5 matplotlib gym==0.25.2 pygame

# %% [markdown]
# https://www.datacamp.com/tutorial/proximal-policy-optimization

# %% [markdown]
# Import the packages in Python

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as f
import torch.distributions as distributions
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
import numpy as np
import gym

# %% [markdown]
# Create two environments - for training and testing

# %%
env_train = gym.make('CartPole-v1')
env_test = gym.make('CartPole-v1')#,render_mode='human'
# Out:
# /opt/anaconda3/envs/ppo/lib/python3.10/site-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /opt/anaconda3/envs/ppo/lib/python3.10/site-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(

# %% [markdown]
# Create the backbone network

# %% [markdown]
# Define the actor-critic model

# %%
class Critic(nn.Module):
    def __init__(self, in_features, hidden_dimensions, out_features, dropout):
        super().__init__()

        self.layer1 = nn.Linear(in_features, hidden_dimensions)
        self.layer2 = nn.Linear(hidden_dimensions, hidden_dimensions)
        self.layer3 = nn.Linear(hidden_dimensions, out_features)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        x = self.layer1(x)
        x = f.relu(x)
        x = self.dropout(x)
        x = self.layer2(x)
        x = f.relu(x)
        x = self.dropout(x)
        x = self.layer3(x)
        return x


class Actor(nn.Module):
    def __init__(self, in_features, hidden_dimensions, out_features, dropout):
        super().__init__()

        self.layer1 = nn.Linear(in_features, hidden_dimensions)
        self.layer2 = nn.Linear(hidden_dimensions, hidden_dimensions)
        self.layer3 = nn.Linear(hidden_dimensions, out_features)
        self.dropout = nn.Dropout(dropout)
        self.Softmax = nn.Softmax(dim=-1)

    def forward(self, x):
        x = self.layer1(x)
        x = f.relu(x)
        x = self.dropout(x)
        x = self.layer2(x)
        x = f.relu(x)
        x = self.dropout(x)
        x = self.layer3(x)
        action_prob = self.Softmax(x)
        dist = distributions.Categorical(action_prob)
        action = dist.sample()
        log_prob_action = dist.log_prob(action)
        return action, log_prob_action, dist

# %% [markdown]
# Create an agent

# %%
def create_agent(hidden_dimensions, dropout):
    INPUT_FEATURES = env_train.observation_space.shape[0]
    HIDDEN_DIMENSIONS = hidden_dimensions
    ACTOR_OUTPUT_FEATURES = env_train.action_space.n
    CRITIC_OUTPUT_FEATURES = 1
    DROPOUT = dropout

    actor = Actor(
            INPUT_FEATURES, HIDDEN_DIMENSIONS, ACTOR_OUTPUT_FEATURES, DROPOUT)
    critic = Critic(
            INPUT_FEATURES, HIDDEN_DIMENSIONS, CRITIC_OUTPUT_FEATURES, DROPOUT)
    return actor, critic

# %% [markdown]
# Define a function to calculate the returns from the rewards

# %%
def calculate_returns(rewards, discount_factor):
    returns = []
    cumulative_reward = 0
    for r in reversed(rewards):
        cumulative_reward = r + cumulative_reward * discount_factor
        returns.insert(0, cumulative_reward)

    returns = torch.tensor(returns)
    # normalize the return
    returns = (returns - returns.mean()) / returns.std()

    return returns

# %% [markdown]
# Define a function to calculate the advantages

# %%
def calculate_advantages(returns, values):
    advantages = returns - values
    # Normalize the advantage
    advantages = (advantages - advantages.mean()) / advantages.std()
    return advantages

# %% [markdown]
# Define a function to calculate surrogate losses

# %%
def calculate_surrogate_loss(
        actions_log_probability_old,
        actions_log_probability_new,
        epsilon,
        advantages):
    advantages = advantages.detach()
    policy_ratio = (
            actions_log_probability_new - actions_log_probability_old
            ).exp()
    surrogate_loss_1 = policy_ratio * advantages
    surrogate_loss_2 = torch.clamp(
            policy_ratio, min=1.0-epsilon, max=1.0+epsilon
            ) * advantages
    surrogate_loss = torch.min(surrogate_loss_1, surrogate_loss_2)
    return surrogate_loss

# %% [markdown]
# Define a function to calculate policy loss and value loss

# %%
def calculate_losses(
        surrogate_loss, entropy, entropy_coefficient, returns, value_pred):
    entropy_bonus = entropy_coefficient * entropy
    policy_loss = -(surrogate_loss + entropy_bonus).sum()
    value_loss = f.smooth_l1_loss(returns, value_pred).sum()
    return policy_loss, value_loss

# %% [markdown]
# Initialize a set of buffers to use during the training

# %%
def init_training():
    states = []
    actions = []
    actions_log_probability = []
    values = []
    rewards = []
    done = False
    episode_reward = 0
    return states, actions, actions_log_probability, values, rewards, done, episode_reward

# %% [markdown]
# Define the forward pass

# %%
def forward_pass(env, actor, critic, optimizer_actor,optimizer_critic, discount_factor):
    states, actions, actions_log_probability, values, rewards, done, episode_reward = init_training()
    state = env.reset()
    actor.train()
    critic.train()
    while not done:
        state = torch.FloatTensor(state).unsqueeze(0)
        states.append(state)

        action, log_prob_action, _ = actor(state)
        value_pred = critic(state)
        
        state, reward, done, _ = env.step(action.item())

        actions.append(action)
        actions_log_probability.append(log_prob_action)
        values.append(value_pred)
        rewards.append(reward)
        episode_reward += reward

    states = torch.cat(states)
    actions = torch.cat(actions)
    actions_log_probability = torch.cat(actions_log_probability)
    values = torch.cat(values).squeeze(-1)
    returns = calculate_returns(rewards, discount_factor)
    advantages = calculate_advantages(returns, values)

    return episode_reward, states, actions, actions_log_probability, advantages, returns

# %% [markdown]
# Define the function to update the policy parameters

# %%
def update_policy(
        actor,
        critic,
        states,
        actions,
        actions_log_probability_old,
        advantages,
        returns,
        optimizer_actor,
        optimizer_critic,
        ppo_steps,
        epsilon,
        entropy_coefficient):

    BATCH_SIZE = 128
    total_policy_loss = 0
    total_value_loss = 0
    actions_log_probability_old = actions_log_probability_old.detach()
    actions = actions.detach()

    training_results_dataset = TensorDataset(
            states,
            actions,
            actions_log_probability_old,
            advantages,
            returns)

    batch_dataset = DataLoader(
            training_results_dataset,
            batch_size=BATCH_SIZE,
            shuffle=False)

    for _ in range(ppo_steps):
        for batch_idx, (states, actions, actions_log_probability_old, advantages, returns) in enumerate(batch_dataset):
            # get new log prob of actions for all input states
            action, actions_log_probability_new, probability_distribution_new = actor(states) 
            value_pred = critic(states)
            value_pred = value_pred.squeeze(-1)
            entropy = probability_distribution_new.entropy()

            # estimate new log probabilities using old actions
            actions_log_probability_new = probability_distribution_new.log_prob(actions)
            surrogate_loss = calculate_surrogate_loss(
                    actions_log_probability_old,
                    actions_log_probability_new,
                    epsilon,
                    advantages)
            policy_loss, value_loss = calculate_losses(
                    surrogate_loss,
                    entropy,
                    entropy_coefficient,
                    returns,
                    value_pred)

            optimizer_actor.zero_grad() 
            optimizer_critic.zero_grad() 
            policy_loss.backward()
            value_loss.backward()
            optimizer_actor.step()
            optimizer_critic.step()
            # calculate the total loss
            # and add it to the total loss
            # for the current batch

            total_policy_loss += policy_loss.item()
            total_value_loss += value_loss.item()

    return total_policy_loss / ppo_steps, total_value_loss / ppo_steps

# %% [markdown]
# Define a function to evaluate the model's (policy's) performance

# %%
def evaluate(env, actor):

    actor.eval()
    rewards = []
    done = False
    episode_reward = 0
    state = env.reset()

    while not done:
        state = torch.FloatTensor(state).unsqueeze(0)
        with torch.no_grad():
            action, log_prob_action, dist = actor(state)
        state, reward, done, _ = env.step(action.item())
        episode_reward += reward

    return episode_reward

# %% [markdown]
# Define a function to plot the rewards

# %%
def plot_train_rewards(train_rewards, reward_threshold):
    plt.figure(figsize=(12, 8))
    plt.plot(train_rewards, label='Train Reward')
    plt.xlabel('Episode', fontsize=20)
    plt.ylabel('Training Reward', fontsize=20)
    plt.hlines(reward_threshold, 0, len(train_rewards), color='y')
    plt.legend(loc='lower right')
    plt.grid()
    plt.show()

# %%
def plot_test_rewards(test_rewards, reward_threshold):
    plt.figure(figsize=(12, 8))
    plt.plot(test_rewards, label='Test Reward')
    plt.xlabel('Episode', fontsize=20)
    plt.ylabel('Testing Reward', fontsize=20)
    plt.hlines(reward_threshold, 0, len(test_rewards), color='y')
    plt.legend(loc='lower right')
    plt.grid()
    plt.show()

# %% [markdown]
# Define a function to plot the losses

# %%
def plot_losses(policy_losses, value_losses):
    plt.figure(figsize=(12, 8))
    plt.plot(value_losses, label='Value Losses')
    plt.plot(policy_losses, label='Policy Losses')
    plt.xlabel('Episode', fontsize=20)
    plt.ylabel('Loss', fontsize=20)
    plt.legend(loc='lower right')
    plt.grid()
    plt.show()

# %%
def evaluate_see(env, actor, render=False, print_model_info=False):
    """
    Avalia o modelo com opções de visualização
    
    Args:
        env: Ambiente Gym
        actor: Modelo do ator
        render: Se True, renderiza o ambiente
        print_model_info: Se True, mostra informações do modelo
    """
    actor.eval()
    episode_reward = 0
    state = env.reset()
    done = False
    
    if print_model_info:
        print("\n" + "="*50)
        print("Informações do Modelo durante Avaliação:")
        print(f"Nome: {actor.__class__.__name__}")
        print(f"Device: {next(actor.parameters()).device}")
        print(f"Parâmetros totais: {sum(p.numel() for p in actor.parameters()):,}")
        print("="*50 + "\n")

    step = 0
    while not done:
        state_tensor = torch.FloatTensor(state).unsqueeze(0)
        
        with torch.no_grad():
            action, log_prob_action, dist = actor(state_tensor)
            
            if print_model_info and step == 0:  # Mostra apenas no primeiro passo
                print(f"\nEstado de entrada (shape): {state_tensor.shape}")
                print(f"Distribuição de ações: {dist}")
                print(f"Ação selecionada: {action.item():.4f}")
                print(f"Log prob da ação: {log_prob_action.item():.4f}")
        
        state, reward, done, _ = env.step(action.item())
        episode_reward += reward
        step += 1
    
    if print_model_info:
        print(f"\nRecompensa total do episódio: {episode_reward:.2f}")
    
    return episode_reward

# %% [markdown]
# Define the main function to train and evaluate the model

# %%
def run_ppo():
    MAX_EPISODES = 700
    DISCOUNT_FACTOR = 0.99
    REWARD_THRESHOLD = 700
    PRINT_INTERVAL = 10
    PPO_STEPS = 8
    N_TRIALS = 100
    EPSILON = 0.2
    ENTROPY_COEFFICIENT = 0.01

    HIDDEN_DIMENSIONS = 64
    DROPOUT = 0.2
    LEARNING_RATE = 0.001

    train_rewards = []
    test_rewards = []
    policy_losses = []
    value_losses = []

    actor, critic = create_agent(HIDDEN_DIMENSIONS, DROPOUT)
    optimizer_actor = optim.Adam(actor.parameters(), lr=LEARNING_RATE)
    optimizer_critic = optim.Adam(critic.parameters(), lr=LEARNING_RATE)

    for episode in range(1, MAX_EPISODES+1):
        train_reward, states, actions, actions_log_probability, advantages, returns = forward_pass(
                env_train,
                actor,
                critic,
                optimizer_actor,
                optimizer_critic,
                DISCOUNT_FACTOR)
        policy_loss, value_loss = update_policy(
                actor,
                critic,
                states,
                actions,
                actions_log_probability,
                advantages,
                returns,
                optimizer_actor,
                optimizer_critic,
                PPO_STEPS,
                EPSILON,
                ENTROPY_COEFFICIENT)
        test_reward = evaluate(env_test, actor)

        policy_losses.append(policy_loss)
        value_losses.append(value_loss)
        train_rewards.append(train_reward)
        test_rewards.append(test_reward)

        mean_train_rewards = np.mean(train_rewards[-N_TRIALS:])
        mean_test_rewards = np.mean(test_rewards[-N_TRIALS:])
        mean_abs_policy_loss = np.mean((policy_losses[-N_TRIALS:]))
        mean_abs_value_loss = np.mean((value_losses[-N_TRIALS:]))

        if episode % PRINT_INTERVAL == 0:
            print(f'Episode: {episode:3d} | Training Reward: {train_reward:.1f} | '
                  f'Testing Reward: {test_reward:.1f} | '
                  f'Mean Train Rewards: {mean_train_rewards:.1f} | '
                  f'Mean Test Rewards: {mean_test_rewards:.1f} | '
                  f'Mean  Policy Loss: {mean_abs_policy_loss:.2f} | '
                  f'Mean  Value Loss: {mean_abs_value_loss:.2f} | '
                  f' Policy Loss: {policy_loss:.2f} | '
                  f'Value Loss: {value_loss:.2f} | ')
            

        if mean_test_rewards >= REWARD_THRESHOLD:
            print(f'Reached reward threshold in {episode} episodes')
            break

        #if episode == (MAX_EPISODES-1):
            #evaluate_see(env_test, actor, render=True, print_model_info=True)

    plot_train_rewards(train_rewards, REWARD_THRESHOLD)
    plot_test_rewards(test_rewards, REWARD_THRESHOLD)
    plot_losses(policy_losses, value_losses)  
    return actor

# %% [markdown]
# Run the main function

# %%
actor = run_ppo()
# Out:
# Episode:  10 | Training Reward: 14.0 | Testing Reward: 33.0 | Mean Train Rewards: 17.0 | Mean Test Rewards: 21.3 | Mean  Policy Loss: -0.16 | Mean  Value Loss: 0.36 |  Policy Loss: -0.47 | Value Loss: 0.33 |
# Episode:  20 | Training Reward: 67.0 | Testing Reward: 73.0 | Mean Train Rewards: 31.1 | Mean Test Rewards: 30.8 | Mean  Policy Loss: -0.22 | Mean  Value Loss: 0.40 |  Policy Loss: 0.50 | Value Loss: 0.52 |
# Episode:  30 | Training Reward: 13.0 | Testing Reward: 43.0 | Mean Train Rewards: 49.8 | Mean Test Rewards: 42.9 | Mean  Policy Loss: -0.01 | Mean  Value Loss: 0.42 |  Policy Loss: 0.16 | Value Loss: 0.48 |
# Episode:  40 | Training Reward: 35.0 | Testing Reward: 115.0 | Mean Train Rewards: 50.1 | Mean Test Rewards: 45.2 | Mean  Policy Loss: 0.01 | Mean  Value Loss: 0.38 |  Policy Loss: 0.39 | Value Loss: 0.13 |
# Episode:  50 | Training Reward: 110.0 | Testing Reward: 148.0 | Mean Train Rewards: 57.4 | Mean Test Rewards: 54.7 | Mean  Policy Loss: 0.13 | Mean  Value Loss: 0.38 |  Policy Loss: 0.65 | Value Loss: 0.36 |
# Episode:  60 | Training Reward: 68.0 | Testing Reward: 130.0 | Mean Train Rewards: 59.9 | Mean Test Rewards: 59.0 | Mean  Policy Loss: 0.20 | Mean  Value Loss: 0.34 |  Policy Loss: -0.78 | Value Loss: 0.11 |
# Episode:  70 | Training Reward: 146.0 | Testing Reward: 213.0 | Mean Train Rewards: 66.9 | Mean Test Rewards: 65.8 | Mean  Policy Loss: 0.32 | Mean  Value Loss: 0.33 |  Policy Loss: 3.05 | Value Loss: 0.46 |
# Episode:  80 | Training Reward: 91.0 | Testing Reward: 96.0 | Mean Train Rewards: 78.0 | Mean Test Rewards: 80.1 | Mean  Policy Loss: 0.29 | Mean  Value Loss: 0.34 |  Policy Loss: 0.03 | Value Loss: 0.29 |
# Episode:  90 | Training Reward: 142.0 | Testing Reward: 107.0 | Mean Train Rewards: 87.7 | Mean Test Rewards: 92.6 | Mean  Policy Loss: 0.29 | Mean  Value Loss: 0.36 |  Policy Loss: 0.90 | Value Loss: 0.16 |
# Episode: 100 | Training Reward: 321.0 | Testing Reward: 282.0 | Mean Train Rewards: 96.2 | Mean Test Rewards: 105.8 | Mean  Policy Loss: 0.32 | Mean  Value Loss: 0.39 |  Policy Loss: 1.37 | Value Loss: 0.34 |
# Episode: 110 | Training Reward: 354.0 | Testing Reward: 304.0 | Mean Train Rewards: 115.9 | Mean Test Rewards: 126.4 | Mean  Policy Loss: 0.43 | Mean  Value Loss: 0.39 |  Policy Loss: 3.45 | Value Loss: 0.54 |
# Episode: 120 | Training Reward: 145.0 | Testing Reward: 273.0 | Mean Train Rewards: 140.8 | Mean Test Rewards: 141.8 | Mean  Policy Loss: 0.58 | Mean  Value Loss: 0.44 |  Policy Loss: 1.79 | Value Loss: 1.23 |
# Episode: 130 | Training Reward: 348.0 | Testing Reward: 213.0 | Mean Train Rewards: 157.0 | Mean Test Rewards: 161.2 | Mean  Policy Loss: 0.45 | Mean  Value Loss: 0.44 |  Policy Loss: -2.27 | Value Loss: 0.42 |
# Episode: 140 | Training Reward: 439.0 | Testing Reward: 336.0 | Mean Train Rewards: 188.6 | Mean Test Rewards: 190.6 | Mean  Policy Loss: 0.53 | Mean  Value Loss: 0.47 |  Policy Loss: 1.40 | Value Loss: 0.91 |
# Episode: 150 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 216.7 | Mean Test Rewards: 217.7 | Mean  Policy Loss: 0.43 | Mean  Value Loss: 0.52 |  Policy Loss: -0.39 | Value Loss: 0.36 |
# Episode: 160 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 253.9 | Mean Test Rewards: 258.1 | Mean  Policy Loss: 0.41 | Mean  Value Loss: 0.62 |  Policy Loss: -1.57 | Value Loss: 0.59 |
# Episode: 170 | Training Reward: 386.0 | Testing Reward: 500.0 | Mean Train Rewards: 286.7 | Mean Test Rewards: 293.5 | Mean  Policy Loss: 0.19 | Mean  Value Loss: 0.72 |  Policy Loss: -0.83 | Value Loss: 1.00 |
# Episode: 180 | Training Reward: 385.0 | Testing Reward: 500.0 | Mean Train Rewards: 309.8 | Mean Test Rewards: 325.3 | Mean  Policy Loss: 0.15 | Mean  Value Loss: 0.79 |  Policy Loss: 4.31 | Value Loss: 1.10 |
# Episode: 190 | Training Reward: 397.0 | Testing Reward: 395.0 | Mean Train Rewards: 337.6 | Mean Test Rewards: 351.6 | Mean  Policy Loss: 0.09 | Mean  Value Loss: 0.87 |  Policy Loss: -1.77 | Value Loss: 1.57 |
# Episode: 200 | Training Reward: 345.0 | Testing Reward: 500.0 | Mean Train Rewards: 355.5 | Mean Test Rewards: 371.0 | Mean  Policy Loss: -0.13 | Mean  Value Loss: 0.89 |  Policy Loss: -1.06 | Value Loss: 0.93 |
# Episode: 210 | Training Reward: 236.0 | Testing Reward: 500.0 | Mean Train Rewards: 378.1 | Mean Test Rewards: 394.0 | Mean  Policy Loss: -0.32 | Mean  Value Loss: 0.96 |  Policy Loss: 0.30 | Value Loss: 0.17 |
# Episode: 220 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 397.5 | Mean Test Rewards: 424.6 | Mean  Policy Loss: -0.56 | Mean  Value Loss: 0.98 |  Policy Loss: 1.26 | Value Loss: 0.78 |
# Episode: 230 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 422.6 | Mean Test Rewards: 448.5 | Mean  Policy Loss: -0.48 | Mean  Value Loss: 1.08 |  Policy Loss: -1.03 | Value Loss: 0.82 |
# Episode: 240 | Training Reward: 339.0 | Testing Reward: 418.0 | Mean Train Rewards: 419.1 | Mean Test Rewards: 446.0 | Mean  Policy Loss: -0.71 | Mean  Value Loss: 1.08 |  Policy Loss: -3.36 | Value Loss: 0.48 |
# Episode: 250 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 426.6 | Mean Test Rewards: 456.7 | Mean  Policy Loss: -0.86 | Mean  Value Loss: 1.11 |  Policy Loss: -5.03 | Value Loss: 1.31 |
# Episode: 260 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 432.1 | Mean Test Rewards: 458.3 | Mean  Policy Loss: -1.00 | Mean  Value Loss: 1.12 |  Policy Loss: -0.39 | Value Loss: 1.40 |
# Episode: 270 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 438.4 | Mean Test Rewards: 462.2 | Mean  Policy Loss: -1.08 | Mean  Value Loss: 1.13 |  Policy Loss: -4.65 | Value Loss: 1.91 |
# Episode: 280 | Training Reward: 500.0 | Testing Reward: 204.0 | Mean Train Rewards: 449.8 | Mean Test Rewards: 458.6 | Mean  Policy Loss: -1.26 | Mean  Value Loss: 1.16 |  Policy Loss: -1.11 | Value Loss: 1.27 |
# Episode: 290 | Training Reward: 410.0 | Testing Reward: 117.0 | Mean Train Rewards: 454.5 | Mean Test Rewards: 456.7 | Mean  Policy Loss: -1.47 | Mean  Value Loss: 1.18 |  Policy Loss: -0.46 | Value Loss: 2.57 |
# Episode: 300 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 463.8 | Mean Test Rewards: 462.4 | Mean  Policy Loss: -1.50 | Mean  Value Loss: 1.22 |  Policy Loss: 1.16 | Value Loss: 1.19 |
# Episode: 310 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 466.9 | Mean Test Rewards: 464.7 | Mean  Policy Loss: -1.68 | Mean  Value Loss: 1.28 |  Policy Loss: 0.00 | Value Loss: 1.68 |
# Episode: 320 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 468.0 | Mean Test Rewards: 464.7 | Mean  Policy Loss: -1.73 | Mean  Value Loss: 1.29 |  Policy Loss: -2.22 | Value Loss: 0.39 |
# Episode: 330 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 468.0 | Mean Test Rewards: 464.7 | Mean  Policy Loss: -1.77 | Mean  Value Loss: 1.30 |  Policy Loss: -1.17 | Value Loss: 1.45 |
# Episode: 340 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 483.0 | Mean Test Rewards: 475.6 | Mean  Policy Loss: -1.83 | Mean  Value Loss: 1.36 |  Policy Loss: -0.70 | Value Loss: 0.80 |
# Episode: 350 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 483.8 | Mean Test Rewards: 476.8 | Mean  Policy Loss: -1.79 | Mean  Value Loss: 1.37 |  Policy Loss: -1.43 | Value Loss: 1.61 |
# Episode: 360 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 481.4 | Mean Test Rewards: 476.8 | Mean  Policy Loss: -1.92 | Mean  Value Loss: 1.39 |  Policy Loss: 0.79 | Value Loss: 1.58 |
# Episode: 370 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 481.4 | Mean Test Rewards: 475.9 | Mean  Policy Loss: -1.87 | Mean  Value Loss: 1.40 |  Policy Loss: -1.36 | Value Loss: 1.64 |
# Episode: 380 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 481.4 | Mean Test Rewards: 477.2 | Mean  Policy Loss: -1.91 | Mean  Value Loss: 1.41 |  Policy Loss: -3.88 | Value Loss: 1.40 |
# Episode: 390 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 482.2 | Mean Test Rewards: 483.6 | Mean  Policy Loss: -1.86 | Mean  Value Loss: 1.40 |  Policy Loss: -2.16 | Value Loss: 1.53 |
# Episode: 400 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 487.9 | Mean Test Rewards: 485.9 | Mean  Policy Loss: -1.86 | Mean  Value Loss: 1.43 |  Policy Loss: -4.56 | Value Loss: 1.61 |
# Episode: 410 | Training Reward: 464.0 | Testing Reward: 500.0 | Mean Train Rewards: 490.3 | Mean Test Rewards: 487.9 | Mean  Policy Loss: -1.53 | Mean  Value Loss: 1.42 |  Policy Loss: 4.46 | Value Loss: 3.08 |
# Episode: 420 | Training Reward: 499.0 | Testing Reward: 500.0 | Mean Train Rewards: 490.2 | Mean Test Rewards: 486.2 | Mean  Policy Loss: -1.54 | Mean  Value Loss: 1.41 |  Policy Loss: 0.68 | Value Loss: 1.55 |
# Episode: 430 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 490.2 | Mean Test Rewards: 486.2 | Mean  Policy Loss: -1.60 | Mean  Value Loss: 1.40 |  Policy Loss: -2.70 | Value Loss: 0.52 |
# Episode: 440 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 490.3 | Mean Test Rewards: 493.1 | Mean  Policy Loss: -1.33 | Mean  Value Loss: 1.41 |  Policy Loss: -0.28 | Value Loss: 0.91 |
# Episode: 450 | Training Reward: 294.0 | Testing Reward: 500.0 | Mean Train Rewards: 490.6 | Mean Test Rewards: 489.9 | Mean  Policy Loss: -1.07 | Mean  Value Loss: 1.38 |  Policy Loss: 1.10 | Value Loss: 1.05 |
# Episode: 460 | Training Reward: 451.0 | Testing Reward: 500.0 | Mean Train Rewards: 487.7 | Mean Test Rewards: 483.7 | Mean  Policy Loss: -0.91 | Mean  Value Loss: 1.29 |  Policy Loss: -0.02 | Value Loss: 0.82 |
# Episode: 470 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 487.2 | Mean Test Rewards: 484.6 | Mean  Policy Loss: -0.82 | Mean  Value Loss: 1.24 |  Policy Loss: -3.56 | Value Loss: 0.89 |
# Episode: 480 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 486.6 | Mean Test Rewards: 487.1 | Mean  Policy Loss: -0.51 | Mean  Value Loss: 1.21 |  Policy Loss: -0.22 | Value Loss: 1.59 |
# Episode: 490 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 485.7 | Mean Test Rewards: 487.1 | Mean  Policy Loss: -0.41 | Mean  Value Loss: 1.19 |  Policy Loss: -2.78 | Value Loss: 1.70 |
# Episode: 500 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 485.7 | Mean Test Rewards: 487.1 | Mean  Policy Loss: -0.32 | Mean  Value Loss: 1.18 |  Policy Loss: -0.50 | Value Loss: 1.50 |
# Episode: 510 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 486.1 | Mean Test Rewards: 487.1 | Mean  Policy Loss: -0.50 | Mean  Value Loss: 1.19 |  Policy Loss: -2.44 | Value Loss: 1.40 |
# Episode: 520 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 486.3 | Mean Test Rewards: 484.5 | Mean  Policy Loss: -0.45 | Mean  Value Loss: 1.23 |  Policy Loss: -2.72 | Value Loss: 1.56 |
# Episode: 530 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 468.1 | Mean Test Rewards: 470.3 | Mean  Policy Loss: -0.53 | Mean  Value Loss: 1.17 |  Policy Loss: -3.79 | Value Loss: 0.94 |
# Episode: 540 | Training Reward: 500.0 | Testing Reward: 120.0 | Mean Train Rewards: 466.8 | Mean Test Rewards: 458.9 | Mean  Policy Loss: -0.70 | Mean  Value Loss: 1.20 |  Policy Loss: -4.49 | Value Loss: 1.66 |
# Episode: 550 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 461.6 | Mean Test Rewards: 458.0 | Mean  Policy Loss: -0.93 | Mean  Value Loss: 1.25 |  Policy Loss: -0.55 | Value Loss: 1.26 |
# Episode: 560 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 466.2 | Mean Test Rewards: 463.5 | Mean  Policy Loss: -0.93 | Mean  Value Loss: 1.31 |  Policy Loss: -2.02 | Value Loss: 0.97 |
# Episode: 570 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 465.7 | Mean Test Rewards: 460.7 | Mean  Policy Loss: -1.03 | Mean  Value Loss: 1.34 |  Policy Loss: -1.76 | Value Loss: 1.21 |
# Episode: 580 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 464.0 | Mean Test Rewards: 457.4 | Mean  Policy Loss: -1.28 | Mean  Value Loss: 1.35 |  Policy Loss: -3.65 | Value Loss: 1.80 |
# Episode: 590 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 464.9 | Mean Test Rewards: 456.1 | Mean  Policy Loss: -1.14 | Mean  Value Loss: 1.31 |  Policy Loss: -1.78 | Value Loss: 0.53 |
# Episode: 600 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 463.9 | Mean Test Rewards: 456.1 | Mean  Policy Loss: -1.01 | Mean  Value Loss: 1.27 |  Policy Loss: 0.28 | Value Loss: 1.12 |
# Episode: 610 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 463.9 | Mean Test Rewards: 456.1 | Mean  Policy Loss: -0.79 | Mean  Value Loss: 1.24 |  Policy Loss: 0.18 | Value Loss: 1.24 |
# Episode: 620 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 463.9 | Mean Test Rewards: 460.3 | Mean  Policy Loss: -0.72 | Mean  Value Loss: 1.22 |  Policy Loss: -3.24 | Value Loss: 0.87 |
# Episode: 630 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 482.1 | Mean Test Rewards: 471.1 | Mean  Policy Loss: -0.68 | Mean  Value Loss: 1.27 |  Policy Loss: -3.11 | Value Loss: 1.11 |
# Episode: 640 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 485.1 | Mean Test Rewards: 482.4 | Mean  Policy Loss: -0.74 | Mean  Value Loss: 1.23 |  Policy Loss: -2.23 | Value Loss: 1.66 |
# Episode: 650 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 492.5 | Mean Test Rewards: 488.3 | Mean  Policy Loss: -0.78 | Mean  Value Loss: 1.24 |  Policy Loss: -4.58 | Value Loss: 1.63 |
# Episode: 660 | Training Reward: 141.0 | Testing Reward: 500.0 | Mean Train Rewards: 488.7 | Mean Test Rewards: 489.1 | Mean  Policy Loss: -0.93 | Mean  Value Loss: 1.27 |  Policy Loss: 0.51 | Value Loss: 0.35 |
# Episode: 670 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 484.6 | Mean Test Rewards: 490.2 | Mean  Policy Loss: -1.01 | Mean  Value Loss: 1.28 |  Policy Loss: -1.75 | Value Loss: 1.53 |
# Episode: 680 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 479.4 | Mean Test Rewards: 491.4 | Mean  Policy Loss: -0.88 | Mean  Value Loss: 1.29 |  Policy Loss: -0.18 | Value Loss: 1.37 |
# Episode: 690 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 479.4 | Mean Test Rewards: 492.7 | Mean  Policy Loss: -0.94 | Mean  Value Loss: 1.34 |  Policy Loss: -0.42 | Value Loss: 1.42 |
# Episode: 700 | Training Reward: 500.0 | Testing Reward: 500.0 | Mean Train Rewards: 480.3 | Mean Test Rewards: 492.7 | Mean  Policy Loss: -1.08 | Mean  Value Loss: 1.39 |  Policy Loss: -0.93 | Value Loss: 1.50 |

# %%
env = gym.make('CartPole-v1',render_mode='human')
evaluate_see(env, actor, render=True, print_model_info=True)
# Out:
# /opt/anaconda3/envs/ppo/lib/python3.10/site-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /opt/anaconda3/envs/ppo/lib/python3.10/site-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /opt/anaconda3/envs/ppo/lib/python3.10/site-packages/pygame/pkgdata.py:25: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_stream, resource_exists
# ==================================================
# Informações do Modelo durante Avaliação:
# Nome: Actor
# Device: cpu
# Parâmetros totais: 4,610
# ==================================================
#
#
# Estado de entrada (shape): torch.Size([1, 4])
# Distribuição de ações: Categorical(probs: torch.Size([1, 2]), logits: torch.Size([1, 2]))
# Ação selecionada: 1.0000
# Log prob da ação: -0.2109
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 env = gym.make('CartPole-v1',render_mode='human')
# ----> 2 evaluate_see(env, actor, render=True, print_model_info=True)
#
# Cell In[17], line 37, in evaluate_see(env, actor, render, print_model_info)
#      34         print(f"Ação selecionada: {action.item():.4f}")
#      35         print(f"Log prob da ação: {log_prob_action.item():.4f}")
# ---> 37 state, reward, done, _ = env.step(action.item())
#      38 episode_reward += reward
#      39 step += 1
#
# File /opt/anaconda3/envs/ppo/lib/python3.10/site-packages/gym/wrappers/time_limit.py:60, in TimeLimit.step(self, action)
#      48 def step(self, action):
#      49     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      50
#      51     Args:
#    (...)
#      57         "TimeLimit.truncated"=False if the environment terminated
#      58     """
#      59     observation, reward, terminated, truncated, info = step_api_compatibility(
# ---> 60         self.env.step(action),
#      61         True,
#      62     )
#      63     self._elapsed_steps += 1
#      65     if self._elapsed_steps >= self._max_episode_steps:
#
# File /opt/anaconda3/envs/ppo/lib/python3.10/site-packages/gym/wrappers/order_enforcing.py:37, in OrderEnforcing.step(self, action)
#      35 if not self._has_reset:
#      36     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 37 return self.env.step(action)
#
# File /opt/anaconda3/envs/ppo/lib/python3.10/site-packages/gym/wrappers/step_api_compatibility.py:52, in StepAPICompatibility.step(self, action)
#      43 def step(self, action):
#      44     """Steps through the environment, returning 5 or 4 items depending on `new_step_api`.
#      45
#      46     Args:
#    (...)
#      50         (observation, reward, terminated, truncated, info) or (observation, reward, done, info)
#      51     """
# ---> 52     step_returns = self.env.step(action)
#      53     if self.new_step_api:
#      54         return step_to_new_api(step_returns)
#
# File /opt/anaconda3/envs/ppo/lib/python3.10/site-packages/gym/wrappers/env_checker.py:39, in PassiveEnvChecker.step(self, action)
#      37     return env_step_passive_checker(self.env, action)
#      38 else:
# ---> 39     return self.env.step(action)
#
# File /opt/anaconda3/envs/ppo/lib/python3.10/site-packages/gym/envs/classic_control/cartpole.py:188, in CartPoleEnv.step(self, action)
#     185     self.steps_beyond_terminated += 1
#     186     reward = 0.0
# --> 188 self.renderer.render_step()
#     189 return np.array(self.state, dtype=np.float32), reward, terminated, False, {}
#
# File /opt/anaconda3/envs/ppo/lib/python3.10/site-packages/gym/utils/renderer.py:58, in Renderer.render_step(self)
#      53 """Computes a frame and save it to the render collection list.
#      54
#      55 This method should be usually called inside environment's step and reset method.
#      56 """
#      57 if self.mode is not None and self.mode not in self.single_render:
# ---> 58     render_return = self.render(self.mode)
#      59     if self.mode not in self.no_returns_render:
#      60         self.render_list.append(render_return)
#
# File /opt/anaconda3/envs/ppo/lib/python3.10/site-packages/gym/envs/classic_control/cartpole.py:301, in CartPoleEnv._render(self, mode)
#     299 if mode == "human":
#     300     pygame.event.pump()
# --> 301     self.clock.tick(self.metadata["render_fps"])
#     302     pygame.display.flip()
#     304 elif mode in {"rgb_array", "single_rgb_array"}:
#
# KeyboardInterrupt:
